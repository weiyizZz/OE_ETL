# %%
# Parameters
DB_PATH          = "../../../DB/oedb_baseline_v3.db"
BENCHMARK_PATH   = "../../../data/input_data/benchmark_trainingset.xlsx"
BENCHMARK_SHEET  = "questions"
MATCHED_CSV_PATH = "matched_questions.csv"
NOTEGROUP_ID_MIN = 1
NOTEGROUP_ID_MAX = 23

EVAL_FIELDS = ["question_content", "main_indicator", "followed_questionID", "following_trigger"]

# %%
import sqlite3
import re
import pandas as pd
from rapidfuzz import fuzz
pd.reset_option("display.max_rows")
pd.reset_option("display.max_colwidth")
def load_etl(db_path, id_min, id_max):
    con = sqlite3.connect(db_path)
    df = pd.read_sql_query(
        """SELECT questionID, notegroupID, question_content,
                  main_indicator, followed_questionID, following_trigger
           FROM questions
           WHERE notegroupID BETWEEN ? AND ?""",
        con, params=(id_min, id_max)
    )
    con.close()
    df["questionID"] = df["questionID"].astype(int)
    return df.set_index("questionID")

def load_benchmark(xlsx_path, sheet, id_min, id_max):
    df = pd.read_excel(xlsx_path, sheet_name=sheet, dtype=str)
    df["notegroupID"] = df["notegroupID"].astype(int)
    df["questionID"]  = df["questionID"].astype(int)
    df = df[df["notegroupID"].between(id_min, id_max)]
    return df.set_index("questionID")

def load_matched(csv_path):
    df = pd.read_csv(csv_path)
    df["etl_questionID"] = df["etl_questionID"].astype(int)
    df["bm_questionID"]  = df["bm_questionID"].astype(int)
    return df

etl     = load_etl(DB_PATH, NOTEGROUP_ID_MIN, NOTEGROUP_ID_MAX)
bm      = load_benchmark(BENCHMARK_PATH, BENCHMARK_SHEET, NOTEGROUP_ID_MIN, NOTEGROUP_ID_MAX)
matched = load_matched(MATCHED_CSV_PATH)

# Build questionID mapping: etl_questionID → bm_questionID and reverse
etl_to_bm = dict(zip(matched["etl_questionID"], matched["bm_questionID"]))
bm_to_etl = dict(zip(matched["bm_questionID"],  matched["etl_questionID"]))

# Derive unmatched sets
matched_etl = set(matched["etl_questionID"])
matched_bm  = set(matched["bm_questionID"])
etl_only    = sorted(set(etl.index) - matched_etl)
bm_only     = sorted(set(bm.index)  - matched_bm)

print(f"ETL records   : {len(etl)}")
print(f"BM records    : {len(bm)}")
print(f"Matched pairs : {len(matched)}")
print(f"ETL-only (FP) : {len(etl_only)}")
print(f"BM-only  (FN) : {len(bm_only)}")
# Out:
# ETL records   : 420
# BM records    : 427
# Matched pairs : 418
# ETL-only (FP) : 2
# BM-only  (FN) : 9

# %%
def normalise_str(val):
    if pd.isna(val) or str(val).strip() in ("", "None", "nan"):
        return None
    s = str(val).strip().lower()
    s = re.sub(r'\s*\n\s*', '\n', s)
    return s

def normalise_followed_questionID(val, id_map):
    """
    Translate a followed_questionID using the ETL→BM or BM→ETL mapping,
    so both sides refer to the same ID space before comparing.
    Returns the mapped ID as a string, or None if null/unmapped.
    """
    if pd.isna(val) or str(val).strip() in ("", "None", "nan"):
        return None
    try:
        qid = int(float(str(val).strip()))
        mapped = id_map.get(qid)
        return str(mapped) if mapped is not None else str(qid)
    except (ValueError, TypeError):
        return None

def compute_counts(etl_val, bm_val, sim_threshold=None):
    """Return (TP, FP, FN, TN) for one field comparison (exact match)."""
    e = normalise_str(etl_val) if not isinstance(etl_val, str) or etl_val else etl_val
    b = normalise_str(bm_val)  if not isinstance(bm_val,  str) or bm_val  else bm_val
    # re-normalise in case values were pre-processed
    e = normalise_str(e)
    b = normalise_str(b)
    if e is not None and b is not None:
        if sim_threshold is not None:
            match = fuzz.ratio(e, b) / 100 >= sim_threshold
        else:
            match = (e == b)
        return (1, 0, 0, 0) if match else (0, 1, 1, 0)
    if e is not None and b is None:
        return (0, 1, 0, 0)   # hallucinated → FP
    if e is None and b is not None:
        return (0, 0, 1, 0)   # missed → FN
    return (0, 0, 0, 1)       # both null → TN

def safe_div(num, den):
    return round(num / den, 4) if den > 0 else None

def metrics_from_counts(TP, FP, FN, TN):
    accuracy  = safe_div(TP + TN, TP + FP + FN + TN)
    precision = safe_div(TP, TP + FP)
    recall    = safe_div(TP, TP + FN)
    f1 = round(2 * precision * recall / (precision + recall), 4) \
         if precision and recall and (precision + recall) > 0 else None
    return dict(TP=TP, FP=FP, FN=FN, TN=TN,
                accuracy=accuracy, precision=precision, recall=recall, F1=f1)

# %%
totals = {f: dict(TP=0, FP=0, FN=0, TN=0) for f in EVAL_FIELDS}

for _, row in matched.iterrows():
    ei = row["etl_questionID"]
    bi = row["bm_questionID"]
    for field in EVAL_FIELDS:
        etl_val = etl.at[ei, field] if field in etl.columns else None
        bm_val  = bm.at[bi, field]  if field in bm.columns  else None

        if field == "followed_questionID":
            etl_val = normalise_followed_questionID(etl_val, etl_to_bm)
            bm_val  = normalise_str(str(bm_val)) if not pd.isna(bm_val) and str(bm_val).strip() not in ("", "None", "nan") else None
            tp, fp, fn, tn = compute_counts(etl_val, bm_val)
        elif field == "question_content":
            tp, fp, fn, tn = compute_counts(etl_val, bm_val, sim_threshold=0.95)
        else:
            tp, fp, fn, tn = compute_counts(etl_val, bm_val)

        totals[field]["TP"] += tp; totals[field]["FP"] += fp
        totals[field]["FN"] += fn; totals[field]["TN"] += tn

# ETL-only rows → every field counts as FP
for ei in etl_only:
    for field in EVAL_FIELDS:
        totals[field]["FP"] += 1

# BM-only rows → every field counts as FN
for bi in bm_only:
    for field in EVAL_FIELDS:
        totals[field]["FN"] += 1

# %%
rows = []
for field in EVAL_FIELDS:
    m = metrics_from_counts(**totals[field])
    rows.append({"field": field, **m})

overall = {k: sum(totals[f][k] for f in EVAL_FIELDS) for k in ("TP","FP","FN","TN")}
m_all = metrics_from_counts(**overall)
rows.append({"field": "OVERALL", **m_all})

results_df = pd.DataFrame(rows).set_index("field")
print(results_df.to_string())
# Out:
#                       TP  FP  FN   TN  accuracy  precision  recall      F1
# field
# question_content     407  13  20    0    0.9250     0.9690  0.9532  0.9610
# main_indicator       125  21  27  274    0.8926     0.8562  0.8224  0.8390
# followed_questionID   92   2   9  326    0.9744     0.9787  0.9109  0.9436
# following_trigger     74   2   9  344    0.9744     0.9737  0.8916  0.9308
# OVERALL              698  38  65  944    0.9410     0.9484  0.9148  0.9313

# %%
# Print mismatched field values for matched pairs
print("=== Mismatched fields in matched pairs ===\n")
for _, row in matched.iterrows():
    ei = row["etl_questionID"]
    bi = row["bm_questionID"]
    mismatches = []
    for field in EVAL_FIELDS:
        etl_val = etl.at[ei, field] if field in etl.columns else None
        bm_val  = bm.at[bi, field]  if field in bm.columns  else None

        if field == "followed_questionID":
            etl_val = normalise_followed_questionID(etl_val, etl_to_bm)
            bm_val  = normalise_str(str(bm_val)) if not pd.isna(bm_val) and str(bm_val).strip() not in ("", "None", "nan") else None

        e = normalise_str(etl_val)
        b = normalise_str(bm_val)
        if e is not None and b is not None:
            if field == "question_content":
                is_mismatch = fuzz.ratio(e, b) / 100 < 0.95
            else:
                is_mismatch = (e != b)
            if is_mismatch:
                mismatches.append((field, etl_val, bm_val))

    if mismatches:
        print(f"etl_questionID={ei}  bm_questionID={bi}")
        for field, ev, bv in mismatches:
            print(f"  [{field}]")
            print(f"    ETL: {ev}")
            print(f"    BM:  {bv}")
        print()
# Out:
# === Mismatched fields in matched pairs ===
#
# etl_questionID=10  bm_questionID=10
#   [main_indicator]
#     ETL: ["bonds", "banden", "bridges", "bruggen"]
#     BM:  ["bridges", "bruggen"]
#
# etl_questionID=15  bm_questionID=15
#   [main_indicator]
#     ETL: ["bridges", "bruggen", "bonds", "banden"]
#     BM:  ["bridges", "bruggen"]
#
# etl_questionID=17  bm_questionID=17
#   [main_indicator]
#     ETL: ["language", "taal", "bridges", "bruggen"]
#     BM:  ["bridges", "bruggen"]
#
# etl_questionID=2  bm_questionID=2
#   [main_indicator]
#     ETL: ["education", "onderwijs", "health", "zorg & welzijn"]
#     BM:  ["health", "zorg & welzijn"]
#
# etl_questionID=5  bm_questionID=5
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "education", "onderwijs"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=9  bm_questionID=9
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "rights and responsibilities", "rechten & verantwoordelijkheden"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=16  bm_questionID=16
#   [main_indicator]
#     ETL: ["bridges", "bruggen", "rights and responsibilities", "rechten & verantwoordelijkheden"]
#     BM:  ["bridges", "bruggen"]
#
# etl_questionID=20  bm_questionID=20
#   [main_indicator]
#     ETL: ["education", "onderwijs"]
#     BM:  ["health", "zorg & welzijn"]
#
# etl_questionID=90  bm_questionID=90
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=91  bm_questionID=91
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=92  bm_questionID=92
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=93  bm_questionID=93
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=95  bm_questionID=95
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=96  bm_questionID=96
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=97  bm_questionID=97
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=98  bm_questionID=98
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=101  bm_questionID=101
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=107  bm_questionID=107
#   [main_indicator]
#     ETL: ["work", "werk & inkomen", "huisvesting & opvang"]
#     BM:  ["work", "werk & inkomen"]
#
# etl_questionID=270  bm_questionID=270
#   [question_content]
#     ETL: Stability
#     BM:  Stability
#  Why did you choose this indicator?
#  Achieve?
#  Obstacles?
#  Actions taken?
#  What would help achieve this goal?
#
# etl_questionID=271  bm_questionID=271
#   [question_content]
#     ETL: Leisure
#     BM:  Leisure
#  Why did you choose this indicator?
#  Achieve?
#  Obstacles?
#  Actions taken?
#  What would help achieve this goal?
#
# etl_questionID=272  bm_questionID=272
#   [question_content]
#     ETL: Health
#     BM:  Health
#  Why did you choose this indicator?
#  Achieve?
#  Obstacles?
#  Actions taken?
#  What would help achieve this goal?
#
# etl_questionID=273  bm_questionID=273
#   [question_content]
#     ETL: Connections with institutions
#     BM:  Connections with institutions
#  Why did you choose this indicator?
#  Achieve?
#  Obstacles?
#  Actions taken?
#  What would help achieve this goal?
#
# etl_questionID=274  bm_questionID=274
#   [question_content]
#     ETL: Social bridges
#     BM:  Social bridges
#  Why did you choose this indicator?
#  Achieve?
#  Obstacles?
#  Actions taken?
#  What would help achieve this goal?
#
# etl_questionID=275  bm_questionID=275
#   [question_content]
#     ETL: Leisure
#     BM:  Leisure
#  Why did you choose this indicator?
#  Achieve?
#  Obstacles?
#  Actions taken?
#  What would help achieve this goal?
#
# etl_questionID=290  bm_questionID=290
#   [question_content]
#     ETL: Collecting feedback
# How would you like the municipality to collect feedback from you?
#     BM:  Collecting feedback
#
# etl_questionID=313  bm_questionID=313
#   [question_content]
#     ETL: Green/Red card statements
# Reading out a statement and respond.
# I/people would face more problems with my/our physical and mental health.
# Accessing healthcare would be more difficult, especially for asylum seekers or those living in the AZC.
# I/people might feel isolated, unsupported, or unheard when dealing with health issues.
# Without the Zorgcafé, I would not have anyone checking in on my mental health.
# I might have gone longer without medication or follow-up for my psychological issues.
# I would feel less safe and less supported in my daily life.
# Because of the Zorgcafé:
# I/people can get the healthcare I/they need more easily.
# The Zorgcafé provides guidance and support, including follow-up and medication management.
# I/people feel listened to and supported, which helps my/our mental health.
# It serves as a bridge between me/people and other healthcare providers (e.g., huisarts, pharmacy).
# I/people feel safer knowing there is a place I/they can go for help.
# I/people get psychological support when needed, even just for talking.
# Reduction in reliance on other healthcare professionals:
# Some issues can be resolved or guided by the Zorgcafé, reducing unnecessary visits to other facilities.
# Zorgcafé helps me/people navigate the healthcare system, ensuring I/they go to the right place for proper care.
# I/people feel safer and more confident in managing my/our health with the support of the Zorgcafé team.
# Because of the Zorgcafé, I don’t have to rely solely on the huisarts for mental health concerns.
# I feel my situation is monitored, and I get help when needed, which reduces stress
#     BM:  Green/Red card statements
#  Reading out a statement and respond.
#
# etl_questionID=393  bm_questionID=393
#   [question_content]
#     ETL: Kun je een moment beschrijven waarop je hulp nodig had van de gemeente of een organisatie?
# Hoe makkelijk of moeilijk was het om de juiste persoon te vinden?
# Hoe heb je het opgelost?
#     BM:  Kun je een moment beschrijven waarop je hulp nodig had van de gemeente of een organisatie?
#  Hoe makkelijk of moeilijk was het om de juiste persoon te vinden?
#
# etl_questionID=391  bm_questionID=391
#   [question_content]
#     ETL: Hoe vind je het tempo en de sfeer in de lessen? Welke lessen heb je gevolgd?
# Past de manier van lesgeven bij jouw niveau en persoonlijke situatie?
#     BM:  Hoe vind je het tempo en de sfeer in de lessen? Welke lessen heb je gevolgd?
#
# etl_questionID=394  bm_questionID=394
#   [question_content]
#     ETL: Hoe ervaar je de ondersteuning en informatie van de gemeente?
# Te veel of te weinig informatie?
# Welke contactvorm werkt het best?
# Geeft dit rust of stress?
#     BM:  Hoe ervaar je de ondersteuning en informatie van de gemeente?
